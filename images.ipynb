# %%
# Import the ImageLoader class from the image_loader.py file
from utils.image_loader import ImageLoader

# %%
# Define the paths to the necessary files and directories
db_images_file = './datasets/SF_XS/sfxs_test_dbImages.npy'
predictions_file = './predictions/temp.npy'
query_file = './datasets/SF_XS/sfxs_test_qImages.npy'
ground_truth_file = './datasets/SF_XS/sfxs_test_gtImages.npy'
images_directory = r'D:\\Github\\gsv-cities\\datasets\\sf_xs_dataset'

# Instantiate the ImageLoader class with the provided arguments
image_loader = ImageLoader(db_images_file, predictions_file, query_file, images_directory, ground_truth_file)

# %%
# import numpy as np
# test = np.load(ground_truth_file, allow_pickle=True)
# test[0]

# %%
# preds = np.load(predictions_file)
# preds[0][0] = test[0][0]
# preds[0][1] = test[0][1]
# np.save('./predictions/temp', preds)

# %%
# Get the path of an image
image_path = image_loader.get_image_path(0)
print("Path of the image:", image_path)
# Out:
# Path of the image: test/database/@0546159.96@4179460.57@10@S@037.76130@-122.47594@vkLR49MX4uuvAqzRZOaKBA@@116@@@@201311@@.jpg

# %%
# Get predictions for a query
query_predictions = image_loader.get_predictions_for_query(0)
print("Predictions for query:", query_predictions)
# Out:
# Predictions for query: [ 2798  6866 20879  6088 10703]

# %%
# Display an image in the database
image_loader.display_image(0)

# %%
# Show a query with its predictions
image_loader.show_query_with_predictions(0)

# %%
# Show multiple queries with  predictions
image_loader.show_multiple_queries_with_predictions([0, 1])
