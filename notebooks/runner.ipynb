# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf gsv-cities

# %%
# !git clone -b my_branch2 https://github.com/aliyassine26/gsv-cities.git
# Out:
# Cloning into 'gsv-cities'...
# remote: Enumerating objects: 964, done.
# remote: Counting objects: 100% (115/115), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 964 (delta 60), reused 71 (delta 44), pack-reused 849
# Receiving objects: 100% (964/964), 214.45 MiB | 23.81 MiB/s, done.
# Resolving deltas: 100% (488/488), done.
# Updating files: 100% (150/150), done.

# %%
# Unzip the file into the target directory
# %%capture
# !unzip /content/drive/MyDrive/GSV_CITIES_DATA/gsv_xs.zip

# %%
# %%capture
# !unzip /content/drive/MyDrive/GSV_CITIES_DATA/sf_xs.zip

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:08
# 🔁 Restarting kernel...

# %%
# Define the path for the new environment
env_path = '/content/gsv_env_main'

# %%
# Create the Conda environment in the specified folder
# !conda create --prefix "$env_path" python=3.8.4 -y
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /content/gsv_env_main
#
#   added / updated specs:
#     - python=3.8.4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.6.2   |       hbcca054_0         152 KB  conda-forge
#     ld_impl_linux-64-2.40      |       hf3520f5_7         691 KB  conda-forge
#     libffi-3.2.1               |    he1b5a44_1007          47 KB  conda-forge
#     libgcc-ng-14.1.0           |       h77fa898_0         822 KB  conda-forge
#     libgomp-14.1.0             |       h77fa898_0         446 KB  conda-forge
#     libsqlite-3.46.0           |       hde9e2c9_0         845 KB  conda-forge
#     libstdcxx-ng-14.1.0        |       hc0a3c3a_0         3.7 MB  conda-forge
#     libzlib-1.2.13             |       h4ab18f5_6          60 KB  conda-forge
#     ncurses-6.5                |       h59595ed_0         867 KB  conda-forge
#     openssl-1.1.1w             |       hd590300_0         1.9 MB  conda-forge
#     pip-24.0                   |     pyhd8ed1ab_0         1.3 MB  conda-forge
#     python-3.8.4               |cpython_h425cb1d_0        71.1 MB  conda-forge
#     setuptools-70.1.1          |     pyhd8ed1ab_0         485 KB  conda-forge
#     sqlite-3.46.0              |       h6d4b2fc_0         840 KB  conda-forge
#     wheel-0.43.0               |     pyhd8ed1ab_1          57 KB  conda-forge
#     zlib-1.2.13                |       h4ab18f5_6          91 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        83.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   ca-certificates    conda-forge/linux-64::ca-certificates-2024.6.2-hbcca054_0
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.40-hf3520f5_7
#   libffi             conda-forge/linux-64::libffi-3.2.1-he1b5a44_1007
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-14.1.0-h77fa898_0
#   libgomp            conda-forge/linux-64::libgomp-14.1.0-h77fa898_0
#   libsqlite          conda-forge/linux-64::libsqlite-3.46.0-hde9e2c9_0
#   libstdcxx-ng       conda-forge/linux-64::libstdcxx-ng-14.1.0-hc0a3c3a_0
#   libzlib            conda-forge/linux-64::libzlib-1.2.13-h4ab18f5_6
#   ncurses            conda-forge/linux-64::ncurses-6.5-h59595ed_0
#   openssl            conda-forge/linux-64::openssl-1.1.1w-hd590300_0
#   pip                conda-forge/noarch::pip-24.0-pyhd8ed1ab_0
#   python             conda-forge/linux-64::python-3.8.4-cpython_h425cb1d_0
#   readline           conda-forge/linux-64::readline-8.2-h8228510_1
#   setuptools         conda-forge/noarch::setuptools-70.1.1-pyhd8ed1ab_0
#   sqlite             conda-forge/linux-64::sqlite-3.46.0-h6d4b2fc_0
#   tk                 conda-forge/linux-64::tk-8.6.13-noxft_h4845f30_101
#   wheel              conda-forge/noarch::wheel-0.43.0-pyhd8ed1ab_1
#   xz                 conda-forge/linux-64::xz-5.2.6-h166bdaf_0
#   zlib               conda-forge/linux-64::zlib-1.2.13-h4ab18f5_6
#
#
#
# Downloading and Extracting Packages:
# python-3.8.4         | 71.1 MB   | :   0% 0/1 [00:00<?, ?it/s]
# libstdcxx-ng-14.1.0  | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# openssl-1.1.1w       | 1.9 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# pip-24.0             | 1.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# ncurses-6.5          | 867 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# libsqlite-3.46.0     | 845 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# sqlite-3.46.0        | 840 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# libgcc-ng-14.1.0     | 822 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 691 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# setuptools-70.1.1    | 485 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# libgomp-14.1.0       | 446 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 152 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 91 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.2.13       | 60 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.43.0         | 57 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.2.1         | 47 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# ncurses-6.5          | 867 KB    | :   7% 0.07384629252984624/1 [00:00<00:01,  1.39s/it]
#
#
# pip-24.0             | 1.3 MB    | :   1% 0.011717545923639992/1 [00:00<00:08,  9.06s/it]
# libstdcxx-ng-14.1.0  | 3.7 MB    | :   0% 0.004221258457524746/1 [00:00<00:27, 27.32s/it]
#
# openssl-1.1.1w       | 1.9 MB    | :   1% 0.008376235295320576/1 [00:00<00:13, 13.50s/it]
#
#
#
#
# libsqlite-3.46.0     | 845 KB    | :   2% 0.018933467075597506/1 [00:00<00:08,  8.70s/it]
# python-3.8.4         | 71.1 MB   | :   0% 0.00021976286508431235/1 [00:00<17:16, 1037.07s/it]
#
#
#
#
#
#
# libgcc-ng-14.1.0     | 822 KB    | :   2% 0.019455913664383113/1 [00:00<00:12, 12.49s/it]
#
#
#
#
#
#
#
# python-3.8.4         | 71.1 MB   | :   1% 0.012526483309805804/1 [00:00<00:20, 20.84s/it]
#
#
#
#
#
# sqlite-3.46.0        | 840 KB    | :   2% 0.019043368295767315/1 [00:00<00:16, 16.76s/it]
#
#
#
#
#
#
#
#
# setuptools-70.1.1    | 485 KB    | :   3% 0.03296977502314163/1 [00:00<00:10, 10.54s/it]
#
#
#
#
#
#
#
#
#
# libgomp-14.1.0       | 446 KB    | :   4% 0.035857088143568416/1 [00:00<00:09, 10.37s/it]
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 152 KB    | :  11% 0.10500208286602365/1 [00:00<00:03,  3.62s/it]
#
#
#
#
#
#
#
#
#
#
#
# python-3.8.4         | 71.1 MB   | :   4% 0.03648063560399585/1 [00:00<00:08,  8.63s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.2.13       | 60 KB     | :  27% 0.2660992999951276/1 [00:00<00:01,  1.62s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.2.1         | 47 KB     | :  34% 0.34131200133325/1 [00:00<00:00,  1.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.43.0         | 57 KB     | :  28% 0.2826630781705571/1 [00:00<00:01,  1.59s/it]
#
# openssl-1.1.1w       | 1.9 MB    | : 100% 1.0/1 [00:00<00:00,  2.02it/s]
#
# python-3.8.4         | 71.1 MB   | :   7% 0.06988459109681132/1 [00:00<00:05,  5.57s/it]
#
#
#
#
# libsqlite-3.46.0     | 845 KB    | : 100% 1.0/1 [00:00<00:00,  1.87it/s]
#
#
#
#
# python-3.8.4         | 71.1 MB   | :  19% 0.19141345548843605/1 [00:00<00:02,  2.75s/it]
#
#
#
#
#
#
# libgcc-ng-14.1.0     | 822 KB    | : 100% 1.0/1 [00:00<00:00,  1.37it/s]
#
#
#
#
#
#
# python-3.8.4         | 71.1 MB   | :  26% 0.2551446863628866/1 [00:00<00:01,  2.25s/it]
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 691 KB    | : 100% 1.0/1 [00:00<00:00,  1.25it/s]
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 691 KB    | : 100% 1.0/1 [00:00<00:00,  1.25it/s]
#
#
# pip-24.0             | 1.3 MB    | : 100% 1.0/1 [00:00<00:00,  1.14it/s]
#
#
# python-3.8.4         | 71.1 MB   | :  33% 0.3320616891423959/1 [00:00<00:01,  1.85s/it]
#
#
#
#
#
# sqlite-3.46.0        | 840 KB    | : 100% 1.0/1 [00:00<00:00,  1.13it/s]
#
#
#
#
#
# python-3.8.4         | 71.1 MB   | :  49% 0.4856759318363303/1 [00:01<00:00,  1.57s/it]
# libstdcxx-ng-14.1.0  | 3.7 MB    | : 100% 1.0/1 [00:01<00:00,  4.94it/s]
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2024 | 152 KB    | : 100% 1.0/1 [00:01<00:00,  1.18s/it]
#
#
#
#
#
#
#
#
#
#
# python-3.8.4         | 71.1 MB   | :  55% 0.550945502766371/1 [00:01<00:00,  1.59s/it]
#
#
#
#
#
#
#
#
# setuptools-70.1.1    | 485 KB    | : 100% 1.0/1 [00:01<00:00,  1.20s/it]
#
#
#
#
#
#
#
#
# setuptools-70.1.1    | 485 KB    | : 100% 1.0/1 [00:01<00:00,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 91 KB     | : 100% 1.0/1 [00:01<00:00,  1.29s/it]
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 91 KB     | : 100% 1.0/1 [00:01<00:00,  1.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.2.13       | 60 KB     | : 100% 1.0/1 [00:01<00:00,  1.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.8.4         | 71.1 MB   | :  61% 0.6148964965059059/1 [00:01<00:00,  1.65s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.2.1         | 47 KB     | : 100% 1.0/1 [00:01<00:00,  1.43s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.2.1         | 47 KB     | : 100% 1.0/1 [00:01<00:00,  1.43s/it]
#
#
#
#
#
#
#
#
#
# libgomp-14.1.0       | 446 KB    | : 100% 1.0/1 [00:01<00:00,  1.34s/it]
#
#
#
#
#
#
#
#
#
# libgomp-14.1.0       | 446 KB    | : 100% 1.0/1 [00:01<00:00,  1.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.43.0         | 57 KB     | : 100% 1.0/1 [00:01<00:00,  1.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.8.4         | 71.1 MB   | :  98% 0.9823400069268762/1 [00:01<00:00,  1.02it/s]
#
#
#
# ncurses-6.5          | 867 KB    | : 100% 1.0/1 [00:01<00:00,  1.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate /content/gsv_env_main
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# %%capture
# !source activate /content/gsv_env_main && pip install -r /content/drive/MyDrive/GSV_CITIES_DATA/requirements.txt

# %%
# %cd gsv-cities/
# Out:
# /content/gsv-cities

# %%
# !source activate /content/gsv_env_main && python3 main.py \
  --batch_size 100 \
  --img_per_place 4 \
  --min_img_per_place 4 \
  --shuffle_all False \
  --random_sample_from_each_place True \
  --image_size "(320, 320)" \
  --num_workers 8 \
  --show_data_stats True \
  --val_set_names '["sfxs_val"]' \
  --test_set_names '["tokyoxs_test"]' \
  --backbone_arch "resnet18" \
  --pretrained True \
  --layers_to_freeze -1 \
  --layers_to_crop '[4]' \
  --agg_arch "cosplace" \
  --agg_config '{"in_dim": 256, "out_dim": 512}' \
  --lr 0.0002 \
  --optimizer "adam" \
  --weight_decay 0 \
  --momentum 0.9 \
  --warmpup_steps 600 \
  --milestones '[5, 10, 15, 25]' \
  --lr_mult 0.3 \
  --loss_name "MultiSimilarityLoss" \
  --miner_name "MultiSimilarityMiner" \
  --miner_margin 0.1 \
  --faiss_gpu True \
  --monitor "sfxs_val/R1" \
  --filename "{self.backbone_arch}_epoch({epoch:02d})_step({step:04d})_R1[{pitts30k_val/R1:.4f}]_R5[{sfxs_val/R5:.4f}]" \
  --auto_insert_metric_name False \
  --save_weights_only True \
  --save_top_k 3 \
  --mode "max" \
  --accelerator "gpu" \
  --devices 1 \
  --default_root_dir "./LOGS/{self.backbone_arch}" \
  --num_sanity_val_steps 0 \
  --precision 32 \
  --max_epochs 30 \
  --check_val_every_n_epoch 1 \
  --reload_dataloaders_every_n_epochs 1 \
  --log_every_n_steps 20 \
  --fast_dev_run False \
  --model_path '/content/drive/MyDrive/GSV_CITIES_DATA/Models/Cosplace_MultiSimilarityLoss_MultiSimilarityMiner_chocolate-firefly-236.ckpt' \
  --experiment_phase "test"

# %%
model = '/content/gsv-cities/visual_place_recognition/o0h7mf0o/checkpoints/self.backbone_arch=0_epoch(epoch=25)_step(step=16276)_R1[pitts30k_val/R1=0.0000]_R5[sfxs_val/R5=0.0066].ckpt'

# %%
# Set up Git user configuration
# !git config --global user.name "alialhousseini"
# !git config --global user.email "alhousseiniali@outlook.com"

# Make changes to your files here

# Add and commit changes
# !git add -A
# !git commit -m "Training Gem - fixed error"

# Push changes to GitHub
# !git push https://alhousseiniali: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@github.com/aliyassine26/gsv-cities.git

# %%
/content/gsv-cities/visual_place_recognition
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-884d3fd38913> in <cell line: 1>()
# ----> 1 content/gsv-cities/visual_place_recognition()
#
# NameError: name 'content' is not defined
